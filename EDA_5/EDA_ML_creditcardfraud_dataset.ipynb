# %% [markdown]
# <a href="https://colab.research.google.com/github/bmaged23/EDA/blob/main/EDA_ML_creditcardfraud_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#  86% 57.0M/66.0M [00:00<00:00, 203MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 200MB/s]

# %%
import zipfile
import os
import pandas as pd
import numpy as np
# Define the path to the zip file
zip_file_path = '/content/creditcardfraud.zip'

# Define the directory where you want to extract the contents
extract_dir = '/content/creditcardfraud'

# Create the directory if it doesn't exist
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f'Files extracted to {extract_dir}')
# Out:
# Files extracted to /content/creditcardfraud

# %%
import pandas as pd
import numpy as np

# %%
url="/content/creditcardfraud/creditcard.csv"
df=pd.read_csv(url)
print(df.columns)
new_df=df
new_df
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# ...

# %%
new_df[new_df["Class"]==0]["Class"].count()
new_df[new_df["Class"]==1]["Class"].count()
# Out:
# 492

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -3.065637e-16 -1.506872e-17 -9.580116e-18 -8.622104e-17 -5.189230e-18
# std    1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -1.996583e+00 -2.879855e+01 -4.403529e+01 -3.187173e+01 -4.013919e+00
# 25%   -8.552120e-01 -4.698918e-01 -3.624707e-01 -5.872142e-01 -5.993788e-01
# 50%   -2.131453e-01  9.245351e-03  3.965683e-02  1.186124e-01 -1.401724e-02
# 75%    9.372174e-01  6.716939e-01  4.867202e-01  6.774569e-01  5.250082e-01
# max    1.642058e+00  1.253351e+00  1.335775e+01  6.187993e+00  1.191874e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.832046e-17  9.979288e-18  1.237432e-17 -3.193372e-18  7.234983e-19
# ...

# %%
from re import S
from sklearn.preprocessing import StandardScaler
col=list(new_df.columns)
scale=StandardScaler()
new_df[col[:-1]]=pd.DataFrame(scale.fit_transform(new_df[col[:-1]]))
print(new_df[[col[-1]]])
# Out:
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 1 columns]

# %%
new_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1      -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2      -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3      -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4      -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690
# 284803  1.641952 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446
# 284804  1.641974  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262
# 284805  1.641974 -0.122755  0.321250  0.463320  0.487192 -0.273836  0.468155
# 284806  1.642058 -0.272331 -0.114899  0.463866 -0.357570 -0.009089 -0.487602
#
# ...

# %%
col=list(new_df.columns)
Y=new_df[col[-1]]
X=new_df[col[:-1]]
print(Y)
print(X)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1      -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2      -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3      -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4      -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690
# 284803  1.641952 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446
# 284804  1.641974  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
#X=np.array(X)
#Y=np.array(Y)
print(X.info())
print(Y.info())
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
model=LogisticRegression(class_weight="balanced")
history=model.fit(X_train,y_train)
y_pred=model.predict(X_test)
y_array=np.array(y_test)
print(accuracy_score(y_train,model.predict(X_train)))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.976966797603634
# 0.9763702117200941
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.92      0.12        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
model=LogisticRegression(class_weight={0:20,1:150})
history=model.fit(X_train,y_train)
y_pred=model.predict(X_test)
y_array=np.array(y_test)
print(accuracy_score(y_train,model.predict(X_train)))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9993021571682503
# 0.9993153330290369
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.80      0.80      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.90      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
