# %% [markdown]
# <a href="https://colab.research.google.com/github/bmaged23/EDA/blob/main/Bank_Marketing_Dataset_EDA_Notebook(Python_For_AI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Data

# %%
# !kaggle kernels pull okandeniz/bank-marketing-classification
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 407, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
import zipfile
import os

# Define the path to the zip file
zip_file_path = '/content/bank-marketing.zip'

# Define the directory where you want to extract the contents
extract_dir = '/content/bank-marketing'

# Create the directory if it doesn't exist
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f'Files extracted to {extract_dir}')
# Out:
# Files extracted to /content/bank-marketing

# %%
#url = "https://www.kaggle.com/datasets/henriqueyamahata/bank-marketing/data"
url="/content/bank-marketing/bank-additional-full.csv"
df = pd.read_csv(url, sep=';', quotechar='"')

# %%
condition="unknown"
for col in df.columns:
  print(col)
  print(df[col].unique())
  print(df[df[col]==condition][col].count())
  print("__________")
# Out:
# age
# [56 57 37 40 45 59 41 24 25 29 35 54 46 50 39 30 55 49 34 52 58 32 38 44
#  42 60 53 47 51 48 33 31 43 36 28 27 26 22 23 20 21 61 19 18 70 66 76 67
#  73 88 95 77 68 75 63 80 62 65 72 82 64 71 69 78 85 79 83 81 74 17 87 91
#  86 98 94 84 92 89]
# 0
# __________
# job
# ['housemaid', 'services', 'admin.', 'blue-collar', 'technician', ..., 'unemployed', 'self-employed', NaN, 'entrepreneur', 'student']
# Length: 12
# Categories (11, object): ['admin.', 'blue-collar', 'entrepreneur', 'housemaid', ..., 'services',
#                           'student', 'technician', 'unemployed']
# 0
# __________
# marital
# ['married', 'single', 'divorced', NaN]
# Categories (3, object): ['divorced', 'married', 'single']
# 0
# __________
# education
# ['basic.4y', 'high.school', 'basic.6y', 'basic.9y', 'professional.course', NaN, 'university.degree', 'illiterate']
# Categories (7, object): ['basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'illiterate',
# ...

# %%
# Display the first few rows of the DataFrame to ensure it's loaded correctly

# Optionally, handle any other cleaning steps such as dealing with missing values
# For example, replacing 'unknown' with NaN
df.replace('unknown', pd.NA, inplace=True)

print(df.head())
# Show basic information about the DataFrame

new_df=df
# Out:
#    age        job  marital    education default housing loan    contact month  \
# 0   56  housemaid  married     basic.4y      no      no   no  telephone   may
# 1   57   services  married  high.school     NaN      no   no  telephone   may
# 2   37   services  married  high.school      no     yes   no  telephone   may
# 3   40     admin.  married     basic.6y      no      no   no  telephone   may
# 4   56   services  married  high.school      no      no  yes  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
# 3         mon  ...         1    999         0  nonexistent          1.1
# 4         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
import pandas as pd

num_duplicates = new_df.duplicated().sum()

print(f'Number of duplicate rows: {num_duplicates}')
new_df.drop_duplicates(inplace=True)
print(new_df)
# Out:
# Number of duplicate rows: 0
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school     NaN      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             40846 non-null  category
#  2   marital         41096 non-null  category
#  3   education       39446 non-null  category
#  4   default         32580 non-null  category
#  5   housing         40186 non-null  category
#  6   loan            40186 non-null  category
#  7   contact         41176 non-null  category
#  8   month           41176 non-null  category
#  9   day_of_week     41176 non-null  category
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  category
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
print(df.describe())
#duration campaign previous
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
new_df["job"]=new_df["job"].astype("category")
new_df["marital"]=new_df["marital"].astype("category")
new_df["default"]=new_df["default"].astype("category")
new_df["education"]=new_df["education"].astype("category")
new_df["housing"]=new_df["housing"].astype("category")
new_df["loan"]=new_df["loan"].astype("category")
new_df["contact"]=new_df["contact"].astype("category")
new_df["month"]=new_df["month"].astype("category")
new_df["day_of_week"]=new_df["day_of_week"].astype("category")
new_df["poutcome"]=new_df["poutcome"].astype("category")
new_df["y"]=new_df["y"].astype("category")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             40846 non-null  category
#  2   marital         41096 non-null  category
#  3   education       39446 non-null  category
#  4   default         32580 non-null  category
#  5   housing         40186 non-null  category
#  6   loan            40186 non-null  category
#  7   contact         41176 non-null  category
#  8   month           41176 non-null  category
#  9   day_of_week     41176 non-null  category
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  category
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
new_df=new_df.drop(columns="default")

# %%
'''new_df["job"].fillna(new_df["job"].mode()[0], inplace=True)
new_df["marital"].fillna(new_df["marital"].mode()[0], inplace=True)
new_df["education"].fillna(new_df["education"].mode()[0], inplace=True)
new_df["housing"].fillna(new_df["housing"].mode()[0], inplace=True)
new_df["loan"].fillna(new_df["loan"].mode()[0], inplace=True)'''
#new_df["default"].fillna(new_df["default"].mode()[0], inplace=True)
new_df = new_df.dropna(axis=0, how='any')
print(new_df)
print("________________________________")
# Assuming df is your DataFrame

# Count the number of rows where 'campaign' > 10 and 'y' == 'yes'
count = df[(df["campaign"] > 3) & (df["y"] == "yes")]["y"].count()

print(count)
print("________________________________")
new_df.info()
# Out:
#        age  job  marital  education  housing  loan  contact  month  \
# 0       56    3        1          0        0     0        1      6
# 1       57    7        1          3        0     0        1      6
# 2       37    7        1          3        1     0        1      6
# 3       40    0        1          1        0     0        1      6
# 4       56    7        1          3        0     1        1      6
# ...    ...  ...      ...        ...      ...   ...      ...    ...
# 41181   37    0        1          6        1     0        0      7
# 41182   29   10        2          0        1     0        0      7
# 41184   46    1        1          5        0     0        0      7
# 41185   56    5        1          6        1     0        0      7
# 41186   44    9        1          5        0     0        0      7
#
#        day_of_week  duration  campaign  pdays  previous  poutcome  \
# 0                1       261         1    999         0         1
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming new_df is already a pandas DataFrame
num_cols = new_df.select_dtypes(include=['number']).columns

for column in num_cols:
    plt.figure(figsize=(5, 3))
    sns.boxplot(y=new_df[column])
    plt.title(f'Box Plot of {column}')
    plt.xlabel(column)
    plt.show()

# %%
#duration campaign previous
new_df=new_df[new_df["age"]<70]
new_df=new_df[new_df["duration"]<550]
new_df=new_df[new_df["campaign"]<7]
new_df=new_df[new_df["previous"]<2]
new_df
# Out:
#        age          job  marital            education housing loan    contact  \
# 0       56    housemaid  married             basic.4y      no   no  telephone
# 1       57     services  married          high.school      no   no  telephone
# 2       37     services  married          high.school     yes   no  telephone
# 3       40       admin.  married             basic.6y      no   no  telephone
# 4       56     services  married          high.school      no  yes  telephone
# ...    ...          ...      ...                  ...     ...  ...        ...
# 41181   37       admin.  married    university.degree     yes   no   cellular
# 41182   29   unemployed   single             basic.4y     yes   no   cellular
# 41184   46  blue-collar  married  professional.course      no   no   cellular
# 41185   56      retired  married    university.degree     yes   no   cellular
# 41186   44   technician  married  professional.course      no   no   cellular
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming new_df is already a pandas DataFrame
num_cols = new_df.select_dtypes(include=['number']).columns

for column in num_cols:
    plt.figure(figsize=(5, 3))
    sns.boxplot(y=new_df[column])
    plt.title(f'Box Plot of {column}')
    plt.xlabel(column)
    plt.show()
new_df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  31222.000000  31222.000000  31222.000000  31222.000000  31222.000000
# mean      39.454007    193.240343      2.051246    978.261674      0.117705
# std        9.496095    123.190396      1.291081    142.006429      0.322264
# min       18.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000     98.000000      1.000000    999.000000      0.000000
# 50%       38.000000    164.000000      2.000000    999.000000      0.000000
# 75%       46.000000    264.000000      3.000000    999.000000      0.000000
# max       69.000000    549.000000      6.000000    999.000000      1.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  31222.000000    31222.000000   31222.000000  31222.000000  31222.000000
# mean       0.117443       93.562806     -40.586625      3.678142   5170.697502
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Sample DataFrame
# new_df = pd.read_csv('path_to_your_data.csv')  # Load your DataFrame if not already

# Initialize LabelEncoder
label_encoders = {}
for column in new_df.select_dtypes(include=['category']).columns:
    le = LabelEncoder()
    new_df[column] = le.fit_transform(new_df[column])
    label_encoders[column] = le  # Save the encoder for later use if needed

# Display the transformed DataFrame
print(new_df.head())
# Out:
#    age  job  marital  education  housing  loan  contact  month  day_of_week  \
# 0   56    3        1          0        0     0        1      6            1
# 1   57    7        1          3        0     0        1      6            1
# 2   37    7        1          3        1     0        1      6            1
# 3   40    0        1          1        0     0        1      6            1
# 4   56    7        1          3        0     1        1      6            1
#
#    duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0       261         1    999         0         1           1.1
# 1       149         1    999         0         1           1.1
# 2       226         1    999         0         1           1.1
# 3       151         1    999         0         1           1.1
# 4       307         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

new_df2 = new_df.drop(columns=['emp.var.rate','euribor3m'])

correlation_matrix = new_df2.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Draw the heatmap with the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add title to the heatmap
plt.title('Correlation Heatmap of Numerical Features')

# Show the plot
plt.show()

# %%
'''import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame: Replace with your actual DataFrame
# new_df2 = pd.read_csv('path_to_your_data.csv')  # Load your DataFrame if not already

# Get numerical columns
num_cols = new_df2.select_dtypes(include=['number']).columns
num_plots = len(num_cols)

# Determine the number of rows and columns for subplots
num_rows = int(np.ceil(num_plots / 3))  # For example, 3 columns
num_cols = min(num_plots, 3)            # Ensure there are no more columns than plots

# Set up the matplotlib figure
plt.figure(figsize=(12, 4 * num_rows))

# Plot histograms for each numerical column
for i, column in enumerate(new_df2.select_dtypes(include=['number']).columns, 1):
    plt.subplot(num_rows, 3, i)
    plt.hist(new_df2[column], bins=30, edgecolor='k')
    plt.title(column)

# Add title to the overall figure
plt.suptitle('Histograms of Numerical Features')

# Adjust layout to make room for titles
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Show the plot
plt.show()'''
# Out:
# "import pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\n\n# Sample DataFrame: Replace with your actual DataFrame\n# new_df2 = pd.read_csv('path_to_your_data.csv')  # Load your DataFrame if not already\n\n# Get numerical columns\nnum_cols = new_df2.select_dtypes(include=['number']).columns\nnum_plots = len(num_cols)\n\n# Determine the number of rows and columns for subplots\nnum_rows = int(np.ceil(num_plots / 3))  # For example, 3 columns\nnum_cols = min(num_plots, 3)            # Ensure there are no more columns than plots\n\n# Set up the matplotlib figure\nplt.figure(figsize=(12, 4 * num_rows))\n\n# Plot histograms for each numerical column\nfor i, column in enumerate(new_df2.select_dtypes(include=['number']).columns, 1):\n    plt.subplot(num_rows, 3, i)\n    plt.hist(new_df2[column], bins=30, edgecolor='k')\n    plt.title(column)\n\n# Add title to the overall figure\nplt.suptitle('Histograms of Numerical Features')\n\n# Adjust layout to make room for titles\nplt.
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming new_df2 is already a pandas DataFrame

# Separate numerical and non-numerical columns
num_cols = new_df2.select_dtypes(include=['number']).columns

# Initialize the scaler
scaler = StandardScaler()

# Scale numerical columns
new_df2_num_scaled = pd.DataFrame(scaler.fit_transform(new_df2[num_cols]), columns=num_cols)

# Combine scaled numerical columns with non-numerical columns

new_df2_num_scaled
# Out:
#             age       job   marital  education   housing      loan   contact  \
# 0      1.742428 -0.177800 -0.282210  -1.766288 -1.083621 -0.430779  1.312634
# 1      1.847736  0.942026 -0.282210  -0.304458 -1.083621 -0.430779  1.312634
# 2     -0.258427  0.942026 -0.282210  -0.304458  0.922832 -0.430779  1.312634
# 3      0.057498 -1.017669 -0.282210  -1.279011 -1.083621 -0.430779  1.312634
# 4      1.742428  0.942026 -0.282210  -0.304458 -1.083621  2.321376  1.312634
# ...         ...       ...       ...        ...       ...       ...       ...
# 31217 -0.258427 -1.017669 -0.282210   1.157372  0.922832 -0.430779 -0.761827
# 31218 -1.100892  1.781896  1.375269  -1.766288  0.922832 -0.430779 -0.761827
# 31219  0.689346 -0.737712 -0.282210   0.670095 -1.083621 -0.430779 -0.761827
# 31220  1.742428  0.382113 -0.282210   1.157372  0.922832 -0.430779 -0.761827
# 31221  0.478730  1.501939 -0.282210   0.670095 -1.083621 -0.430779 -0.761827
#
# ...

# %%
hash
# Out:
# <function hash(obj, /)>

# %%
#smoth blance the data
#give weight for the model in the random state
